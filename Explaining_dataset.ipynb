# %% [markdown]
# # A brief Explainer for each of the dataset objects
#
# The datasets are stored within a H5 file. These are dictionary like data structures that allows us to conveniently store the various things we need.
#
# Key points:
# 1. Each of the h5 files are stored in the h5Datasets folder

# %%
import h5py

# %%
dataset = h5py.File('Data/h5Datasets/googlenet/googlenet_summe.h5')

# %% [markdown]
# Each data-point within our dataset is stored as individual keys

# %%
dataset.keys()
# Out:
# <KeysViewHDF5 ['video_1', 'video_10', 'video_11', 'video_12', 'video_13', 'video_14', 'video_15', 'video_16', 'video_17', 'video_18', 'video_19', 'video_2', 'video_20', 'video_21', 'video_22', 'video_23', 'video_24', 'video_25', 'video_3', 'video_4', 'video_5', 'video_6', 'video_7', 'video_8', 'video_9']>

# %% [markdown]
# Each of the data-points store the various points we'd need for training and inference

# %%
dataset['video_1'].keys()
# Out:
# <KeysViewHDF5 ['downsampled_shot_boundaries', 'features', 'gtscore', 'gtsummary', 'n_frame_per_seg', 'n_frames', 'n_steps', 'positions', 'shot_bounds', 'user_summary', 'video_name']>

# %% [markdown]
# The main points which are relevant for our experiments are:
# 1. Features,
# 2. gtscore,
# 3. n_frames,
# 4. user_summary
